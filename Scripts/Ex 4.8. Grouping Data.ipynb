# %%
# Importing libraries
import pandas as pd
import numpy as np
import os

# %%
# Import path of data
path = r'C:\Users\nikik\17-12-2025 Instacart Basket Analysis'

# %%
# 1. importing ords_prods_merge dataframe
ords_prods_merge = pd.read_pickle(os.path.join(path, 'Data', 'Prepared Data', 'df_ords_prods_merge_new_columns.pkl'))

# %%
ords_prods_merge.shape
# Out:
# (32404859, 20)

# %% [markdown]
# # 2. Aggregating Data

# %%
# peforming single aggregation
department_mean_orders = ords_prods_merge.groupby('department_id').agg({'order_number': ['mean']})

# %%
department_mean_orders
# Out:
#               order_number
#                       mean
# department_id
# 1                15.457838
# 2                17.277920
# 3                17.170395
# 4                17.811403
# 5                15.215751
# 6                16.439806
# 7                17.225802
# 8                15.340650
# 9                15.895474
# 10               20.197148
# 11               16.170638
# 12               15.887671
# 13               16.583536
# 14               16.773669
# 15               16.165037
# 16               17.665606
# 17               15.694469
# 18               19.310397
# 19               17.177343
# 20               16.473447
# 21               22.902379

# %% [markdown]
# # 3. The average order_number varies across departments, with department 21 having the highest mean orders (22.9) and department 5 among the lowest (15.2). This indicates that some departments are consistently reordered more frequently. Compared to a subset, the full dataset provides a more accurate and representative picture of ordering patterns across all departments.

# %% [markdown]
# # 4. Follow the instructions in the Exercise for creating a loyalty flag for existing customers using the transform() and loc() functions.

# %%
# Creating loyalt flag
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
ords_prods_merge.head(15)
# Out:
#     product_id                product_name  aisle_id  department_id  prices  \
# 0            1  Chocolate Sandwich Cookies        61             19     5.8
# 1            1  Chocolate Sandwich Cookies        61             19     5.8
# 2            1  Chocolate Sandwich Cookies        61             19     5.8
# 3            1  Chocolate Sandwich Cookies        61             19     5.8
# 4            1  Chocolate Sandwich Cookies        61             19     5.8
# 5            1  Chocolate Sandwich Cookies        61             19     5.8
# 6            1  Chocolate Sandwich Cookies        61             19     5.8
# 7            1  Chocolate Sandwich Cookies        61             19     5.8
# 8            1  Chocolate Sandwich Cookies        61             19     5.8
# 9            1  Chocolate Sandwich Cookies        61             19     5.8
# 10           1  Chocolate Sandwich Cookies        61             19     5.8
# ...

# %%
# Deriving Columns with loc()
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: loyalty_flag, dtype: int64

# %%
# Checking the output
ords_prods_merge.head(15)
# Out:
#     product_id                product_name  aisle_id  department_id  prices  \
# 0            1  Chocolate Sandwich Cookies        61             19     5.8
# 1            1  Chocolate Sandwich Cookies        61             19     5.8
# 2            1  Chocolate Sandwich Cookies        61             19     5.8
# 3            1  Chocolate Sandwich Cookies        61             19     5.8
# 4            1  Chocolate Sandwich Cookies        61             19     5.8
# 5            1  Chocolate Sandwich Cookies        61             19     5.8
# 6            1  Chocolate Sandwich Cookies        61             19     5.8
# 7            1  Chocolate Sandwich Cookies        61             19     5.8
# 8            1  Chocolate Sandwich Cookies        61             19     5.8
# 9            1  Chocolate Sandwich Cookies        61             19     5.8
# 10           1  Chocolate Sandwich Cookies        61             19     5.8
# ...

# %% [markdown]
# # 5. The marketing team at Instacart wants to know whether there’s a difference between the spending habits of the three types of customers you identified. Use the loyalty flag you created and check the basic statistics of the product prices for each loyalty category (Loyal Customer, Regular Customer, and New Customer).

# %%
ords_prods_merge.groupby('loyalty_flag').agg({'prices': ['mean', 'min', 'max']})
# Out:
#                      prices
#                        mean  min      max
# loyalty_flag
# Loyal customer    10.386336  1.0  99999.0
# New customer      13.294670  1.0  99999.0
# Regular customer  12.495717  1.0  99999.0

# %% [markdown]
# # Analysis of Spending Habits by Customer Type
#   The average product prices differ slightly across customer types: loyal customers tend to purchase slightly cheaper items on average (10.39) compared to regular (12.50) and new customers (13.29). The minimum and maximum prices are the same for all groups, suggesting that while all customers occasionally buy very cheap or very expensive products, loyal customers generally spend less per order on average.

# %% [markdown]
# # Create a spending flag

# %%
# Aggregating data
ords_prods_merge['avg_product_price'] = ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)

# %%
ords_prods_merge[['user_id' , 'avg_product_price']].head(15)
# Out:
#     user_id  avg_product_price
# 0       138           6.935811
# 1       138           6.935811
# 2       709           7.930208
# 3       764           4.972414
# 4       764           4.972414
# 5       777           6.935398
# 6       825           5.957576
# 7       910           6.680000
# 8      1052           7.162500
# 9      1052           7.162500
# 10     1379           5.813636
# 11     1480           5.081633
# 12     1480           5.081633
# 13     1480           5.081633
# 14     1494           6.803797

# %% [markdown]
# # # 6.  Create a spending flag for each user based on the average price across all their orders using the following criteria:
# If the mean of the prices of products purchased by a user is lower than 10, then flag them as a “Low spender.”

# %%
ords_prods_merge.loc[ords_prods_merge['avg_product_price'] < 10, 'spending_flag'] = 'Low spender'

# %% [markdown]
# # If the mean of the prices of products purchased by a user is higher than or equal to 10, then flag them as a “High spender.”

# %%
ords_prods_merge.loc[ords_prods_merge['avg_product_price'] >= 10, 'spending_flag'] = 'High spender'

# %%
ords_prods_merge['spending_flag'].value_counts(dropna = False)
# Out:
# Low spender     31770614
# High spender      634245
# Name: spending_flag, dtype: int64

# %%
# checking relevant column
ords_prods_merge[['user_id', 'avg_product_price', 'spending_flag']].head(15)
# Out:
#     user_id  avg_product_price spending_flag
# 0       138           6.935811   Low spender
# 1       138           6.935811   Low spender
# 2       709           7.930208   Low spender
# 3       764           4.972414   Low spender
# 4       764           4.972414   Low spender
# 5       777           6.935398   Low spender
# 6       825           5.957576   Low spender
# 7       910           6.680000   Low spender
# 8      1052           7.162500   Low spender
# 9      1052           7.162500   Low spender
# 10     1379           5.813636   Low spender
# 11     1480           5.081633   Low spender
# 12     1480           5.081633   Low spender
# 13     1480           5.081633   Low spender
# 14     1494           6.803797   Low spender

# %% [markdown]
# # 7. In order to send relevant notifications to users within the app (for instance, asking users if they want to buy the same item again), the Instacart team wants you to determine frequent versus non-frequent customers. Create an order frequency flag

# %%
# Aggregating data
ords_prods_merge['median_days_between_orders'] = ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
# checking relevant columns
ords_prods_merge[['user_id', 'days_since_prior_order', 'median_days_between_orders']].head(15)
# Out:
#     user_id  days_since_prior_order  median_days_between_orders
# 0       138                     3.0                         8.0
# 1       138                    20.0                         8.0
# 2       709                     6.0                         6.0
# 3       764                     0.0                         9.0
# 4       764                     9.0                         9.0
# 5       777                    26.0                        11.0
# 6       825                    30.0                        19.0
# 7       910                    30.0                         3.5
# 8      1052                    19.0                         9.5
# 9      1052                    15.0                         9.5
# 10     1379                     0.0                        20.0
# 11     1480                     7.0                         7.0
# 12     1480                     7.0                         7.0
# 13     1480                    12.0                         7.0
# ...

# %% [markdown]
# # If the median of “days_since_prior_order” is higher than 20, then the customer should be labeled a “Non-frequent customer.”

# %%
ords_prods_merge.loc[ords_prods_merge['median_days_between_orders'] > 20, 'order_frequency_flag'] = 'Non-frequent customer'

# %% [markdown]
# # If the median is higher than 10 and lower than or equal to 20, then the customer should be labeled a “Regular customer.”

# %%
ords_prods_merge.loc[(ords_prods_merge['median_days_between_orders'] <= 20) & (ords_prods_merge['median_days_between_orders'] > 10), 'order_frequency_flag'] = 'Regular customer'

# %% [markdown]
# # If the median is lower than or equal to 10, then the customer should be labeled a “Frequent customer.”

# %%
ords_prods_merge.loc[ords_prods_merge['median_days_between_orders'] <= 10, 'order_frequency_flag'] = 'Frequent customer'

# %%
ords_prods_merge['order_frequency_flag'].value_counts(dropna = False)
# Out:
# Frequent customer        22796659
# Regular customer          6921472
# Non-frequent customer     2686728
# Name: order_frequency_flag, dtype: int64

# %%
ords_prods_merge[['user_id', 'days_since_prior_order', 'median_days_between_orders', 'order_frequency_flag']].head(15)
# Out:
#     user_id  days_since_prior_order  median_days_between_orders  \
# 0       138                     3.0                         8.0
# 1       138                    20.0                         8.0
# 2       709                     6.0                         6.0
# 3       764                     0.0                         9.0
# 4       764                     9.0                         9.0
# 5       777                    26.0                        11.0
# 6       825                    30.0                        19.0
# 7       910                    30.0                         3.5
# 8      1052                    19.0                         9.5
# 9      1052                    15.0                         9.5
# 10     1379                     0.0                        20.0
# 11     1480                     7.0                         7.0
# 12     1480                     7.0                         7.0
# 13     1480                    12.0                         7.0
# ...

# %% [markdown]
# # Export your dataframe as a pickle file and store it correctly in your “Prepared Data” folder.

# %%
ords_prods_merge.to_pickle(os.path.join(path, 'Data', 'Prepared Data', 'orders_products_grouped.pkl'))
