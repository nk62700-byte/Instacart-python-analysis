# %% [markdown]
# # 01. Impoerting libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02. Python data types

# %%
# Method 1
# Code 3 different ways of reaching a result of 100 by adding or subtracting numeric variables.
x = 40

# %%
y = 60

# %%
z= x+y

# %%
print(z)
# Out:
# 100

# %%
# Method 2
a = 150

# %%
b = 50

# %%
print(a-b)
# Out:
# 100

# %%
# Method 3
m = 25

# %%
n = 75

# %%
p = m+n

# %%
print(p)
# Out:
# 100

# %%
# Code 2 floating-point variables and divide them by each other
x = 5.58

# %%
y = 4.5

# %%
print(x/y)
# Out:
# 1.24

# %%
a = float(20)

# %%
b= float(4)

# %%
c = a/b

# %%
print(c)
# Out:
# 5.0

# %%
# Construct a short word made of separate strings (you’ll need to concatenate some strings!).
m = 'py'

# %%
n = 'thon'

# %%
m+n
# Out:
# 'python'

# %%
# Construct 2 short sentences made of separate strings.
part1 = 'python'
part2 = 'is'
part3 = 'fun'
sentence1 = part1+part2+part3

# %%
print(sentence1)
# Out:
# pythonisfun

# %%
A = 'data'
B = 'science'
C = 'rocks!'
sentence2 = A+B+C

# %%
print(sentence2)
# Out:
# datasciencerocks!

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\nikik\\17-12-2025 Instacart Basket Analysis\\Scripts'
