# %%
# importing libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Part 1

# %%
path = r'C:\Users\nikik\17-12-2025 Instacart Basket Analysis'

# %% [markdown]
# # Import new customer data set as a dataframe.

# %%
# Import customer data file
df_customers = pd.read_csv(os.path.join(path, 'Data', 'Original Data', 'customers.csv'), index_col = False)

# %%
df_customers.head()
# Out:
#    user_id First Name    Surnam  Gender       STATE  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    n_dependants fam_status  income
# 0             3    married  165665
# 1             0     single   59285
# 2             2    married   99568
# 3             0     single   42049
# 4             1    married   40374

# %%
df_customers.shape
# Out:
# (206209, 10)

# %% [markdown]
# # Wrangle the data so that it follows consistent logic; for example, rename columns with illogical names and drop columns that don’t add anything to your analysis.

# %%
# Renaming columns
df_customers.rename(columns = {'first name': 'First Name', 'Surnam': 'Surname', 'Gender': 'gender', 'STATE': 'state', 'Age': 'age', 'n_dependants': 'n_dependents', 'fam_status' :'family_status'}, inplace = True)

# %%
# check the output
df_customers.head()
# Out:
#    user_id First Name   Surname  gender       state  age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    n_dependents family_status  income
# 0             3       married  165665
# 1             0        single   59285
# 2             2       married   99568
# 3             0        single   42049
# 4             1       married   40374

# %%
# checkig data types
df_customers.dtypes
# Out:
# user_id           int32
# First Name       object
# Surname          object
# gender           object
# state            object
# age               int32
# date_joined      object
# n_dependents      int32
# family_status    object
# income            int32
# dtype: object

# %%
# keeping necessary columns
#df_customers = df_customers[['user_id', 'gender', 'age', 'n_dependents', 'income']]

# %%
# convert int64 to int32
int_cols = ['user_id', 'age', 'n_dependents', 'income']
for col in int_cols:
    df_customers[col] = df_customers[col].astype('int32')

# %%
df_customers.dtypes
# Out:
# user_id           int32
# First Name       object
# Surname          object
# gender           object
# state            object
# age               int32
# date_joined      object
# n_dependents      int32
# family_status    object
# income            int32
# dtype: object

# %% [markdown]
# # Complete the fundamental data quality and consistency checks you’ve learned throughout this Achievement; for example, check for and address missing values and duplicates, and convert any mixed-type data.

# %%
df_customers.describe()
# Out:
#              user_id            age   n_dependents         income
# count  206209.000000  206209.000000  206209.000000  206209.000000
# mean   103105.000000      49.501646       1.499823   94632.852548
# std     59527.555167      18.480962       1.118433   42473.786988
# min         1.000000      18.000000       0.000000   25903.000000
# 25%     51553.000000      33.000000       0.000000   59874.000000
# 50%    103105.000000      49.000000       1.000000   93547.000000
# 75%    154657.000000      66.000000       3.000000  124244.000000
# max    206209.000000      81.000000       3.000000  593901.000000

# %%
# checking for mixed type data
for col in df_customers.columns.tolist():
    weird = (df_customers[[col]].applymap(type) != df_customers
             [[col]].iloc[0].apply(type)).any(axis = 1)
    if len(df_customers[weird]) > 0:
        print(col)

# %%
df_customers['First Name'] = df_customers['First Name'].astype('str')

# %%
df_customers['First Name'].dtype
# Out:
# dtype('O')

# %% [markdown]
# # Missing values

# %%
# checking for missing values
df_customers.isnull().sum()
# Out:
# user_id          0
# First Name       0
# Surname          0
# gender           0
# state            0
# age              0
# date_joined      0
# n_dependents     0
# family_status    0
# income           0
# dtype: int64

# %%
# No missing values found

# %% [markdown]
# # Checking for Duplicates

# %%
df_dups = df_customers[df_customers.duplicated()]

# %%
df_dups
# Out:
# Empty DataFrame
# Columns: [user_id, First Name, Surname, gender, state, age, date_joined, n_dependents, family_status, income]
# Index: []

# %%
# No duplicates found

# %% [markdown]
# # Combine your customer data with the rest of your prepared Instacart data. (Hint: Make sure the key columns are the same data type!)

# %%
# Importing the combined dataframe

df_prepared_dataframe = pd.read_pickle(os.path.join(path, 'Data', 'Prepared Data', 'orders_products_grouped.pkl'))

# %%
df_prepared_dataframe.shape
# Out:
# (32404859, 26)

# %%
df_prepared_dataframe.dtypes
# Out:
# product_id                       int64
# product_name                    object
# aisle_id                         int64
# department_id                    int64
# prices                         float64
# Unnamed: 0.1                     int64
# Unnamed: 0                       int64
# order_id                         int64
# user_id                          int64
# order_number                     int64
# orders_day_of_week               int64
# order_hour_of_day                int64
# days_since_prior_order         float64
# add_to_cart_order                int64
# reordered                        int64
# _merge                        category
# price_range_loc                 object
# busiest_day                     object
# busiest_days                    object
# busiest_period_of_day           object
# max_order                        int64
# loyalty_flag                    object
# avg_product_price              float64
# spending_flag                   object
# ...

# %%
df_prepared_dataframe.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    Unnamed: 0.1  Unnamed: 0  order_id  user_id  order_number  ...  \
# 0          1987        1987   3139998      138            28  ...
# 1          1989        1989   1977647      138            30  ...
# 2         11433       11433    389851      709             2  ...
# 3         12198       12198    652770      764             1  ...
# 4         12200       12200   1813452      764             3  ...
#
#      price_range_loc     busiest_day  busiest_days  busiest_period_of_day  \
# ...

# %%
# columns to keep
cols_to_keep = ['order_id', 'user_id', 'order_hour_of_day', 'prices', 'loyalty_flag', 'department_id', 'product_name', 'product_id']
df_prepared_dataframe = df_prepared_dataframe[cols_to_keep]

# %%
# convert int64 to int32
int_cols = ['product_id', 'department_id', 'user_id', 'order_id', 'order_hour_of_day']
for col in int_cols:
    df_prepared_dataframe[col] = df_prepared_dataframe[col].astype('int32')
# Out:
# <ipython-input-43-11fcf8a0820f>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_prepared_dataframe[col] = df_prepared_dataframe[col].astype('int32')

# %%
# checking key columns are same
df_prepared_dataframe['user_id'].dtype
# Out:
# dtype('int32')

# %%
df_prepared_dataframe['user_id'].dtype
# Out:
# dtype('int32')

# %%
# checking unique values
df_prepared_dataframe['user_id'].nunique()
# Out:
# 206209

# %%
df_customers['user_id'].nunique()
# Out:
# 206209

# %%
df_merging = df_prepared_dataframe.merge(df_customers, on = 'user_id', how ='left')

# %%
df_merging.head()
# Out:
#    order_id  user_id  order_hour_of_day  prices      loyalty_flag  \
# 0   3139998      138                 11     5.8  Regular customer
# 1   1977647      138                 17     5.8  Regular customer
# 2    389851      709                 21     5.8      New customer
# 3    652770      764                 13     5.8      New customer
# 4   1813452      764                 17     5.8      New customer
#
#    department_id                product_name  product_id First Name Surname  \
# 0             19  Chocolate Sandwich Cookies           1    Charles     Cox
# 1             19  Chocolate Sandwich Cookies           1    Charles     Cox
# 2             19  Chocolate Sandwich Cookies           1    Deborah   Glass
# 3             19  Chocolate Sandwich Cookies           1    Heather   Myers
# 4             19  Chocolate Sandwich Cookies           1    Heather   Myers
#
#    gender      state  age date_joined  n_dependents family_status  income
# ...

# %%
df_merging.shape
# Out:
# (32404859, 17)

# %% [markdown]
# # Exporting new dataframe as pickle file

# %%
df_merging.to_pickle(os.path.join(path, 'Data','Prepared Data', 'dataframe_new.pkl'))
